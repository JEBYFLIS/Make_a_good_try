# %%
#BIG DATA PROCESS AND PANDAS ABILITY TRAINING

# %%
#import package
import pandas as pd 
import numpy as np

# %%
#load dataset 
import seaborn as sb
df = sb.load_dataset('titanic')
df.sample(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 599         1       1    male  49.0      1      0   56.9292        C  First
# 741         0       1    male  36.0      1      0   78.8500        S  First
# 501         0       3  female  21.0      0      0    7.7500        Q  Third
# 306         1       1  female   NaN      0      0  110.8833        C  First
# 188         0       3    male  40.0      1      1   15.5000        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# 599    man        True    A    Cherbourg   yes  False
# 741    man        True    C  Southampton    no  False
# 501  woman       False  NaN   Queenstown    no   True
# 306  woman       False  NaN    Cherbourg   yes   True
# 188    man        True  NaN   Queenstown    no  False

# %%
df.to_csv('titanic.csv')

# %%
data = pd.read_csv('titanic.csv')
data.shape
# Out:
# (891, 16)

# %%
print('头部5条数据\n',data.head(5))
print('尾部5条数据\n',data.tail(5))
# Out:
# 头部5条数据
#     Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True
# 尾部5条数据
#       Unnamed: 0  survived  pclass     sex   age  sibsp  parch   fare embarked  \
# ...

# %%
print('将缺失值取代为0')
data_1 = data.fillna(0)
data_1.head(5)
# Out:
# 将缺失值取代为0
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True    0  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False    0  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True    0  Southampton    no   True

# %%
print('All featrues names\n',data.columns)
print('ALL matrix values\n', data.values)
print('ALL row names\n', data.index)
# Out:
# All featrues names
#  Index(['Unnamed: 0', 'survived', 'pclass', 'sex', 'age', 'sibsp', 'parch',
#        'fare', 'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')
# ALL matrix values
#  [[0 0 3 ... 'Southampton' 'no' False]
#  [1 1 1 ... 'Cherbourg' 'yes' False]
#  [2 1 3 ... 'Southampton' 'yes' True]
#  ...
#  [888 0 3 ... 'Southampton' 'no' False]
#  [889 1 1 ... 'Cherbourg' 'yes' True]
#  [890 0 3 ... 'Queenstown' 'no' True]]
# ALL row names
#  RangeIndex(start=0, stop=891, step=1)

# %%
data.dtypes
# Out:
# Unnamed: 0       int64
# survived         int64
# pclass           int64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked        object
# class           object
# who             object
# adult_male        bool
# deck            object
# embark_town     object
# alive           object
# alone             bool
# dtype: object

# %%
print('选取其中某一部分的数组')
print('选取某特定一列')
print(data['age'])
print('选取第n列')
print(data[data.columns[2]])
# Out:
# 选取其中某一部分的数组
# 选取某特定一列
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64
# 选取第n列
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
print('根据行列位置取数据')
print('假设我们选取第3行的某两个参数')
print(data.loc[[3], ['sex', 'class']])
# Out:
# 根据行列位置取数据
# 假设我们选取第3行的某两个参数
#       sex  class
# 3  female  First

# %%
print('按照特定的行和列进行')
print('x-y行,m-n列\n', data.iloc[0:5, 0:4])
# Out:
# 按照特定的行和列进行
# x-y行,m-n列
#     Unnamed: 0  survived  pclass     sex
# 0           0         0       3    male
# 1           1         1       1  female
# 2           2         1       3  female
# 3           3         1       1  female
# 4           4         0       3    male

# %%
print('使用位置选择某些个特定行和特定列')
print('选择a,b,c行以及x,y,z列\n', data.iloc[[1,3,5], [2,5,6]])
# Out:
# 使用位置选择某些个特定行和特定列
# 选择a,b,c行以及x,y,z列
#     pclass  sibsp  parch
# 1       1      1      0
# 3       1      1      0
# 5       3      0      0

# %%
print('条件筛选某一列的数据')
data_select = data[data.fare > 5]
print(data_select)
print('筛选符合条件的数据\n', data[data['alive'].isin(['yes'])])#选择的是这一列中包含某些特定参数的额
# Out:
# 条件筛选某一列的数据
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
print('给列赋值')
print('给某一列赋值\n', data_select['embarked'] == np.array([0]*len(data_select)))
# Out:
# 给列赋值
# 给某一列赋值
#  0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: embarked, Length: 874, dtype: bool

# %%
data_select
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...
